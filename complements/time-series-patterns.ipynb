# %% [markdown]
# <h1 style='font-size:40px'>
#     <a href='https://otexts.com/fpp2/tspatterns.html'>Time Series Patterns</a></h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             As séries temporais podem ter um conjunto de características.
#         </li>
#     </ul>
#  </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Trend</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Uma tendência seria qualquer aumento ou diminuição observável a longo prazo na série.
#         </li>
#      </ul>
# </div>

# %% [markdown]
#  <center style='font-size:20px;margin-top:20px'>
#         <figure>
#             <img src='../img/complements-trend.png'>
#             <figcaption style='font-size:15px'>
#                 Exemplo de gráfico com uma tendência de queda.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Seasonality</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A sazonalidade seria qualquer padrão que ocorre devido a um fator sazonal.
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Cyclicity</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A ciclicidade seria a repetição de padrões em um período não específico de tempo (o que é diferente da sazonalidade).
#         </li>
#      </ul>
# </div>

# %% [markdown]
#  <center style='font-size:20px;margin-top:20px'>
#         <figure>
#             <img src='../img/complements-seasonality.png'>
#             <figcaption style='font-size:15px'>
#                 Observe que esse gráfico apresenta um padrão sazonal de queda sempre no início dos anos. Tambḿ contém ciclicidade de subidas e descidas nos valores ao longo do tempo.
#             </figcaption>
#         </figure>
#     </center>

# %%
! git add .
! git commit -am 'Definir Autocorrelation'
! git push
# Out:
# [master 6b22005] Continuar de 1.4 Forecasting data and methods "An explanatory model is useful because it "
#  1 file changed, 11 insertions(+), 12 deletions(-)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 580 bytes | 580.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/felipesveiga/time-series.git
#    bf1e6a7..6b22005  master -> master

# %% [markdown]
# <p style='color:red'> Definir Autocorrelation
