# %% [markdown]
# <h1 style='font-size:40px'>
#     <a href='https://otexts.com/fpp2/autocorrelation.html'>Autocorrelation</a></h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A auto-correlação de uma série seria a correlação dela com sua versão de $n$ time-steps de lag.
#         </li>
#         <li>
#             Uma série que não possui autocorrelação com uma grande quantidade de suas versões de lag é chamada de <i> white noise</i>.
#         </li>
#     </ul>
#  </div>

# %% [markdown]
#  <center style='font-size:20px;margin-top:20px'>
#         <figure>
#             <img src='../img/complements-acf.png'>
#             <figcaption style='font-size:15px'>
#                 Podemos plotar as autocorrelações de uma série para cada nível $n$ de lag num gráfico de Autocorrelation Function (ACF).
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h2 style='font-size:30px'> White Noise</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Seja $T$ o tamanho da série sendo analisada, consideramos essa um ruído branco caso 95% das autocorrelações ficarem no intervalo de $\pm\frac{2}{T}$.
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Continuar livro-site da seção "3.2/Mathematical transformations"'
! git push
# Out:
# [master 3737d98] Continuar livro-site da seção "3.1/Seasonal Naïve Method"
#  2 files changed, 119 insertions(+), 44 deletions(-)
#  create mode 100644 complements/autocorrelation.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.33 KiB | 1.33 MiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 3 local objects.
# To https://github.com/felipesveiga/time-series.git
#    767618e..3737d98  master -> master

# %% [markdown]
# <p style='color:red'> Defini Autocorrelation; Continuar livro-site da seção "3.2/Mathematical transformations"
